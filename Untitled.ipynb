# %%
# !pip install ee geemap
# Out:
# Collecting ee
#   Downloading ee-0.2.tar.gz (3.0 kB)
#   Preparing metadata (setup.py) ... done
# Collecting geemap
#   Downloading geemap-0.34.5-py2.py3-none-any.whl.metadata (12 kB)
# Collecting blessings (from ee)
#   Downloading blessings-1.7-py3-none-any.whl.metadata (19 kB)
# Collecting bqplot (from geemap)
#   Downloading bqplot-0.12.43-py2.py3-none-any.whl.metadata (6.4 kB)
# Collecting colour (from geemap)
#   Downloading colour-0.1.5-py2.py3-none-any.whl.metadata (18 kB)
# Collecting earthengine-api>=1.0.0 (from geemap)
#   Downloading earthengine_api-1.1.2-py3-none-any.whl.metadata (1.8 kB)
# Collecting eerepr>=0.0.4 (from geemap)
#   Downloading eerepr-0.0.4-py3-none-any.whl.metadata (4.0 kB)
# Collecting folium>=0.17.0 (from geemap)
#   Downloading folium-0.17.0-py2.py3-none-any.whl.metadata (3.8 kB)
# Collecting geocoder (from geemap)
#   Downloading geocoder-1.38.1-py2.py3-none-any.whl.metadata (14 kB)
# Collecting ipyevents (from geemap)
#   Downloading ipyevents-2.0.2-py3-none-any.whl.metadata (2.9 kB)
# Collecting ipyfilechooser>=0.6.0 (from geemap)
#   Downloading ipyfilechooser-0.6.0-py3-none-any.whl.metadata (6.4 kB)
# Collecting ipyleaflet>=0.19.2 (from geemap)
#   Downloading ipyleaflet-0.19.2-py3-none-any.whl.metadata (5.3 kB)
# Collecting ipytree (from geemap)
#   Downloading ipytree-0.2.2-py2.py3-none-any.whl.metadata (849 bytes)
# Requirement already satisfied: matplotlib in /opt/anaconda3/lib/python3.11/site-packages (from geemap) (3.8.0)
# Requirement already satisfied: numpy in /opt/anaconda3/lib/python3.11/site-packages (from geemap) (1.26.4)
# Requirement already satisfied: pandas in /opt/anaconda3/lib/python3.11/site-packages (from geemap) (2.1.4)
# Requirement already satisfied: plotly in /opt/anaconda3/lib/python3.11/site-packages (from geemap) (5.9.0)
# Collecting pyperclip (from geemap)
#   Downloading pyperclip-1.9.0.tar.gz (20 kB)
#   Preparing metadata (setup.py) ... done
# Collecting pyshp>=2.3.1 (from geemap)
#   Downloading pyshp-2.3.1-py2.py3-none-any.whl.metadata (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.0/56.0 kB 484.8 kB/s eta 0:00:00 0:00:01
# Collecting python-box (from geemap)
#   Downloading python_box-7.2.0-cp311-cp311-macosx_10_9_universal2.whl.metadata (7.8 kB)
# Collecting scooby (from geemap)
#   Downloading scooby-0.10.0-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: setuptools in /opt/anaconda3/lib/python3.11/site-packages (from geemap) (68.2.2)
# Collecting google-cloud-storage (from earthengine-api>=1.0.0->geemap)
#   Downloading google_cloud_storage-2.18.2-py2.py3-none-any.whl.metadata (9.1 kB)
# Collecting google-api-python-client>=1.12.1 (from earthengine-api>=1.0.0->geemap)
#   Downloading google_api_python_client-2.147.0-py2.py3-none-any.whl.metadata (6.7 kB)
# Collecting google-auth>=1.4.1 (from earthengine-api>=1.0.0->geemap)
#   Downloading google_auth-2.35.0-py2.py3-none-any.whl.metadata (4.7 kB)
# Collecting google-auth-httplib2>=0.0.3 (from earthengine-api>=1.0.0->geemap)
#   Downloading google_auth_httplib2-0.2.0-py2.py3-none-any.whl.metadata (2.2 kB)
# Collecting httplib2<1dev,>=0.9.2 (from earthengine-api>=1.0.0->geemap)
#   Downloading httplib2-0.22.0-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: requests in /opt/anaconda3/lib/python3.11/site-packages (from earthengine-api>=1.0.0->geemap) (2.31.0)
# Collecting branca>=0.6.0 (from folium>=0.17.0->geemap)
#   Downloading branca-0.8.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: jinja2>=2.9 in /opt/anaconda3/lib/python3.11/site-packages (from folium>=0.17.0->geemap) (3.1.3)
# Requirement already satisfied: xyzservices in /opt/anaconda3/lib/python3.11/site-packages (from folium>=0.17.0->geemap) (2022.9.0)
# Requirement already satisfied: ipywidgets in /opt/anaconda3/lib/python3.11/site-packages (from ipyfilechooser>=0.6.0->geemap) (7.6.5)
# Collecting jupyter-leaflet<0.20,>=0.19 (from ipyleaflet>=0.19.2->geemap)
#   Downloading jupyter_leaflet-0.19.2-py3-none-any.whl.metadata (2.4 kB)
# Collecting traittypes<3,>=0.2.1 (from ipyleaflet>=0.19.2->geemap)
#   Downloading traittypes-0.2.1-py2.py3-none-any.whl.metadata (1.0 kB)
# Requirement already satisfied: six in /opt/anaconda3/lib/python3.11/site-packages (from blessings->ee) (1.16.0)
# Requirement already satisfied: traitlets>=4.3.0 in /opt/anaconda3/lib/python3.11/site-packages (from bqplot->geemap) (5.7.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/lib/python3.11/site-packages (from pandas->geemap) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.11/site-packages (from pandas->geemap) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/anaconda3/lib/python3.11/site-packages (from pandas->geemap) (2023.3)
# Requirement already satisfied: click in /opt/anaconda3/lib/python3.11/site-packages (from geocoder->geemap) (8.1.7)
# Requirement already satisfied: future in /opt/anaconda3/lib/python3.11/site-packages (from geocoder->geemap) (0.18.3)
# Collecting ratelim (from geocoder->geemap)
#   Downloading ratelim-0.1.6-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/lib/python3.11/site-packages (from matplotlib->geemap) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/lib/python3.11/site-packages (from matplotlib->geemap) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/lib/python3.11/site-packages (from matplotlib->geemap) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/anaconda3/lib/python3.11/site-packages (from matplotlib->geemap) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/lib/python3.11/site-packages (from matplotlib->geemap) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /opt/anaconda3/lib/python3.11/site-packages (from matplotlib->geemap) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/anaconda3/lib/python3.11/site-packages (from matplotlib->geemap) (3.0.9)
# Requirement already satisfied: tenacity>=6.2.0 in /opt/anaconda3/lib/python3.11/site-packages (from plotly->geemap) (8.2.2)
# Collecting google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5 (from google-api-python-client>=1.12.1->earthengine-api>=1.0.0->geemap)
#   Downloading google_api_core-2.20.0-py3-none-any.whl.metadata (2.7 kB)
# Collecting uritemplate<5,>=3.0.1 (from google-api-python-client>=1.12.1->earthengine-api>=1.0.0->geemap)
#   Downloading uritemplate-4.1.1-py2.py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /opt/anaconda3/lib/python3.11/site-packages (from google-auth>=1.4.1->earthengine-api>=1.0.0->geemap) (4.2.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/anaconda3/lib/python3.11/site-packages (from google-auth>=1.4.1->earthengine-api>=1.0.0->geemap) (0.2.8)
# Collecting rsa<5,>=3.1.4 (from google-auth>=1.4.1->earthengine-api>=1.0.0->geemap)
#   Downloading rsa-4.9-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: ipykernel>=4.5.1 in /opt/anaconda3/lib/python3.11/site-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap) (6.28.0)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /opt/anaconda3/lib/python3.11/site-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.2.0)
# Requirement already satisfied: nbformat>=4.2.0 in /opt/anaconda3/lib/python3.11/site-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap) (5.9.2)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /opt/anaconda3/lib/python3.11/site-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap) (3.5.2)
# Requirement already satisfied: ipython>=4.0.0 in /opt/anaconda3/lib/python3.11/site-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap) (8.20.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /opt/anaconda3/lib/python3.11/site-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap) (3.0.9)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/lib/python3.11/site-packages (from jinja2>=2.9->folium>=0.17.0->geemap) (2.1.3)
# Collecting google-cloud-core<3.0dev,>=2.3.0 (from google-cloud-storage->earthengine-api>=1.0.0->geemap)
#   Downloading google_cloud_core-2.4.1-py2.py3-none-any.whl.metadata (2.7 kB)
# Collecting google-resumable-media>=2.7.2 (from google-cloud-storage->earthengine-api>=1.0.0->geemap)
#   Downloading google_resumable_media-2.7.2-py2.py3-none-any.whl.metadata (2.2 kB)
# Collecting google-crc32c<2.0dev,>=1.0 (from google-cloud-storage->earthengine-api>=1.0.0->geemap)
#   Downloading google_crc32c-1.6.0-cp311-cp311-macosx_12_0_arm64.whl.metadata (2.3 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.11/site-packages (from requests->earthengine-api>=1.0.0->geemap) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.11/site-packages (from requests->earthengine-api>=1.0.0->geemap) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.11/site-packages (from requests->earthengine-api>=1.0.0->geemap) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.11/site-packages (from requests->earthengine-api>=1.0.0->geemap) (2024.2.2)
# Requirement already satisfied: decorator in /opt/anaconda3/lib/python3.11/site-packages (from ratelim->geocoder->geemap) (5.1.1)
# Collecting googleapis-common-protos<2.0.dev0,>=1.56.2 (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client>=1.12.1->earthengine-api>=1.0.0->geemap)
#   Downloading googleapis_common_protos-1.65.0-py2.py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0.dev0,>=3.19.5 in /opt/anaconda3/lib/python3.11/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client>=1.12.1->earthengine-api>=1.0.0->geemap) (3.20.3)
# Collecting proto-plus<2.0.0dev,>=1.22.3 (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client>=1.12.1->earthengine-api>=1.0.0->geemap)
#   Downloading proto_plus-1.24.0-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: appnope in /opt/anaconda3/lib/python3.11/site-packages (from ipykernel>=4.5.1->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.1.2)
# Requirement already satisfied: comm>=0.1.1 in /opt/anaconda3/lib/python3.11/site-packages (from ipykernel>=4.5.1->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.1.2)
# Requirement already satisfied: debugpy>=1.6.5 in /opt/anaconda3/lib/python3.11/site-packages (from ipykernel>=4.5.1->ipywidgets->ipyfilechooser>=0.6.0->geemap) (1.6.7)
# Requirement already satisfied: jupyter-client>=6.1.12 in /opt/anaconda3/lib/python3.11/site-packages (from ipykernel>=4.5.1->ipywidgets->ipyfilechooser>=0.6.0->geemap) (8.6.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /opt/anaconda3/lib/python3.11/site-packages (from ipykernel>=4.5.1->ipywidgets->ipyfilechooser>=0.6.0->geemap) (5.5.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in /opt/anaconda3/lib/python3.11/site-packages (from ipykernel>=4.5.1->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.1.6)
# Requirement already satisfied: nest-asyncio in /opt/anaconda3/lib/python3.11/site-packages (from ipykernel>=4.5.1->ipywidgets->ipyfilechooser>=0.6.0->geemap) (1.6.0)
# Requirement already satisfied: psutil in /opt/anaconda3/lib/python3.11/site-packages (from ipykernel>=4.5.1->ipywidgets->ipyfilechooser>=0.6.0->geemap) (5.9.0)
# Requirement already satisfied: pyzmq>=24 in /opt/anaconda3/lib/python3.11/site-packages (from ipykernel>=4.5.1->ipywidgets->ipyfilechooser>=0.6.0->geemap) (25.1.2)
# Requirement already satisfied: tornado>=6.1 in /opt/anaconda3/lib/python3.11/site-packages (from ipykernel>=4.5.1->ipywidgets->ipyfilechooser>=0.6.0->geemap) (6.3.3)
# Requirement already satisfied: jedi>=0.16 in /opt/anaconda3/lib/python3.11/site-packages (from ipython>=4.0.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.18.1)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /opt/anaconda3/lib/python3.11/site-packages (from ipython>=4.0.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in /opt/anaconda3/lib/python3.11/site-packages (from ipython>=4.0.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (2.15.1)
# Requirement already satisfied: stack-data in /opt/anaconda3/lib/python3.11/site-packages (from ipython>=4.0.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /opt/anaconda3/lib/python3.11/site-packages (from ipython>=4.0.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (4.8.0)
# Requirement already satisfied: fastjsonschema in /opt/anaconda3/lib/python3.11/site-packages (from nbformat>=4.2.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (2.16.2)
# Requirement already satisfied: jsonschema>=2.6 in /opt/anaconda3/lib/python3.11/site-packages (from nbformat>=4.2.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (4.19.2)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /opt/anaconda3/lib/python3.11/site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.4.1->earthengine-api>=1.0.0->geemap) (0.4.8)
# Requirement already satisfied: notebook>=4.4.1 in /opt/anaconda3/lib/python3.11/site-packages (from widgetsnbextension~=3.5.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (7.0.8)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /opt/anaconda3/lib/python3.11/site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.8.3)
# Requirement already satisfied: attrs>=22.2.0 in /opt/anaconda3/lib/python3.11/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/anaconda3/lib/python3.11/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/anaconda3/lib/python3.11/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/anaconda3/lib/python3.11/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.10.6)
# Requirement already satisfied: platformdirs>=2.5 in /opt/anaconda3/lib/python3.11/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=4.5.1->ipywidgets->ipyfilechooser>=0.6.0->geemap) (3.10.0)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /opt/anaconda3/lib/python3.11/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (2.10.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.22.1 in /opt/anaconda3/lib/python3.11/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (2.25.1)
# Requirement already satisfied: jupyterlab<4.1,>=4.0.2 in /opt/anaconda3/lib/python3.11/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (4.0.11)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in /opt/anaconda3/lib/python3.11/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.2.3)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/anaconda3/lib/python3.11/site-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.7.0)
# Requirement already satisfied: wcwidth in /opt/anaconda3/lib/python3.11/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=4.0.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.2.5)
# Requirement already satisfied: executing in /opt/anaconda3/lib/python3.11/site-packages (from stack-data->ipython>=4.0.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.8.3)
# Requirement already satisfied: asttokens in /opt/anaconda3/lib/python3.11/site-packages (from stack-data->ipython>=4.0.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (2.0.5)
# Requirement already satisfied: pure-eval in /opt/anaconda3/lib/python3.11/site-packages (from stack-data->ipython>=4.0.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.2.2)
# Requirement already satisfied: anyio>=3.1.0 in /opt/anaconda3/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (4.2.0)
# Requirement already satisfied: argon2-cffi in /opt/anaconda3/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (21.3.0)
# Requirement already satisfied: jupyter-events>=0.6.0 in /opt/anaconda3/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.8.0)
# Requirement already satisfied: jupyter-server-terminals in /opt/anaconda3/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.4.4)
# Requirement already satisfied: nbconvert>=6.4.4 in /opt/anaconda3/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (7.10.0)
# Requirement already satisfied: overrides in /opt/anaconda3/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (7.4.0)
# Requirement already satisfied: prometheus-client in /opt/anaconda3/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.14.1)
# Requirement already satisfied: send2trash>=1.8.2 in /opt/anaconda3/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in /opt/anaconda3/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.17.1)
# Requirement already satisfied: websocket-client in /opt/anaconda3/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.58.0)
# Requirement already satisfied: async-lru>=1.0.0 in /opt/anaconda3/lib/python3.11/site-packages (from jupyterlab<4.1,>=4.0.2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (2.0.4)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /opt/anaconda3/lib/python3.11/site-packages (from jupyterlab<4.1,>=4.0.2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (2.2.0)
# Requirement already satisfied: babel>=2.10 in /opt/anaconda3/lib/python3.11/site-packages (from jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (2.11.0)
# Requirement already satisfied: json5>=0.9.0 in /opt/anaconda3/lib/python3.11/site-packages (from jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.9.6)
# Requirement already satisfied: sniffio>=1.1 in /opt/anaconda3/lib/python3.11/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (1.3.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in /opt/anaconda3/lib/python3.11/site-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (2.0.7)
# Requirement already satisfied: pyyaml>=5.3 in /opt/anaconda3/lib/python3.11/site-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (6.0.1)
# Requirement already satisfied: rfc3339-validator in /opt/anaconda3/lib/python3.11/site-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /opt/anaconda3/lib/python3.11/site-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.1.1)
# Requirement already satisfied: beautifulsoup4 in /opt/anaconda3/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (4.12.2)
# Requirement already satisfied: bleach!=5.0.0 in /opt/anaconda3/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (4.1.0)
# Requirement already satisfied: defusedxml in /opt/anaconda3/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /opt/anaconda3/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.1.2)
# Requirement already satisfied: mistune<4,>=2.0.3 in /opt/anaconda3/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (2.0.4)
# Requirement already satisfied: nbclient>=0.5.0 in /opt/anaconda3/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.8.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /opt/anaconda3/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (1.5.0)
# Requirement already satisfied: tinycss2 in /opt/anaconda3/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (1.2.1)
# Requirement already satisfied: argon2-cffi-bindings in /opt/anaconda3/lib/python3.11/site-packages (from argon2-cffi->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (21.2.0)
# Requirement already satisfied: webencodings in /opt/anaconda3/lib/python3.11/site-packages (from bleach!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.5.1)
# Collecting fqdn (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->ipyfilechooser>=0.6.0->geemap)
#   Downloading fqdn-1.5.1-py3-none-any.whl.metadata (1.4 kB)
# Collecting isoduration (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->ipyfilechooser>=0.6.0->geemap)
#   Downloading isoduration-20.11.0-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: jsonpointer>1.13 in /opt/anaconda3/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (2.1)
# Collecting uri-template (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->ipyfilechooser>=0.6.0->geemap)
#   Downloading uri_template-1.3.0-py3-none-any.whl.metadata (8.8 kB)
# Collecting webcolors>=1.11 (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->ipyfilechooser>=0.6.0->geemap)
#   Downloading webcolors-24.8.0-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: cffi>=1.0.1 in /opt/anaconda3/lib/python3.11/site-packages (from argon2-cffi-bindings->argon2-cffi->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (1.16.0)
# Requirement already satisfied: soupsieve>1.2 in /opt/anaconda3/lib/python3.11/site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (2.5)
# Requirement already satisfied: pycparser in /opt/anaconda3/lib/python3.11/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (2.21)
# Requirement already satisfied: arrow>=0.15.0 in /opt/anaconda3/lib/python3.11/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (1.2.3)
# Downloading geemap-0.34.5-py2.py3-none-any.whl (2.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 2.7 MB/s eta 0:00:00a 0:00:01
# Downloading earthengine_api-1.1.2-py3-none-any.whl (454 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 454.3/454.3 kB 6.4 MB/s eta 0:00:00ta 0:00:01
# Downloading eerepr-0.0.4-py3-none-any.whl (9.7 kB)
# Downloading folium-0.17.0-py2.py3-none-any.whl (108 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.4/108.4 kB 4.6 MB/s eta 0:00:00
# Downloading ipyfilechooser-0.6.0-py3-none-any.whl (11 kB)
# Downloading ipyleaflet-0.19.2-py3-none-any.whl (31 kB)
# Downloading pyshp-2.3.1-py2.py3-none-any.whl (46 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.5/46.5 kB 1.9 MB/s eta 0:00:00
# Downloading blessings-1.7-py3-none-any.whl (18 kB)
# Downloading bqplot-0.12.43-py2.py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 7.7 MB/s eta 0:00:0000:0100:01
# Downloading colour-0.1.5-py2.py3-none-any.whl (23 kB)
# Downloading geocoder-1.38.1-py2.py3-none-any.whl (98 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.6/98.6 kB 3.2 MB/s eta 0:00:00
# Downloading ipyevents-2.0.2-py3-none-any.whl (101 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.8/101.8 kB 4.1 MB/s eta 0:00:00
# Downloading ipytree-0.2.2-py2.py3-none-any.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 7.1 MB/s eta 0:00:00a 0:00:01
# Downloading python_box-7.2.0-cp311-cp311-macosx_10_9_universal2.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 7.3 MB/s eta 0:00:00a 0:00:01
# Downloading scooby-0.10.0-py3-none-any.whl (18 kB)
# Downloading branca-0.8.0-py3-none-any.whl (25 kB)
# Downloading google_api_python_client-2.147.0-py2.py3-none-any.whl (12.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.2/12.2 MB 9.1 MB/s eta 0:00:0000:0100:01
# Downloading google_auth-2.35.0-py2.py3-none-any.whl (208 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.0/209.0 kB 5.2 MB/s eta 0:00:0000:01
# Downloading google_auth_httplib2-0.2.0-py2.py3-none-any.whl (9.3 kB)
# Downloading httplib2-0.22.0-py3-none-any.whl (96 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.9/96.9 kB 3.7 MB/s eta 0:00:00
# Downloading jupyter_leaflet-0.19.2-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 11.1 MB/s eta 0:00:00a 0:00:01
# Downloading traittypes-0.2.1-py2.py3-none-any.whl (8.6 kB)
# Downloading google_cloud_storage-2.18.2-py2.py3-none-any.whl (130 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.5/130.5 kB 4.7 MB/s eta 0:00:00
# Downloading ratelim-0.1.6-py2.py3-none-any.whl (4.0 kB)
# Downloading google_api_core-2.20.0-py3-none-any.whl (142 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 142.2/142.2 kB 4.6 MB/s eta 0:00:00
# Downloading google_cloud_core-2.4.1-py2.py3-none-any.whl (29 kB)
# Downloading google_crc32c-1.6.0-cp311-cp311-macosx_12_0_arm64.whl (30 kB)
# Downloading google_resumable_media-2.7.2-py2.py3-none-any.whl (81 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.3/81.3 kB 3.7 MB/s eta 0:00:00
# Downloading rsa-4.9-py3-none-any.whl (34 kB)
# Downloading uritemplate-4.1.1-py2.py3-none-any.whl (10 kB)
# Downloading googleapis_common_protos-1.65.0-py2.py3-none-any.whl (220 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 220.9/220.9 kB 8.8 MB/s eta 0:00:00
# Downloading proto_plus-1.24.0-py3-none-any.whl (50 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.1/50.1 kB 1.6 MB/s eta 0:00:00
# Downloading webcolors-24.8.0-py3-none-any.whl (15 kB)
# Downloading fqdn-1.5.1-py3-none-any.whl (9.1 kB)
# Downloading isoduration-20.11.0-py3-none-any.whl (11 kB)
# Downloading uri_template-1.3.0-py3-none-any.whl (11 kB)
# Building wheels for collected packages: ee, pyperclip
#   Building wheel for ee (setup.py) ... done
#   Created wheel for ee: filename=ee-0.2-py3-none-any.whl size=3655 sha256=9e1fb3d85d8ca6f611a1cc077ce348bf15ad4e974c6d82f48542a882b62dc09f
#   Stored in directory: /Users/daniyar/Library/Caches/pip/wheels/a0/6d/ee/1d25db5c1257f6b86266fa4c20a2439110c42e8759486066f7
#   Building wheel for pyperclip (setup.py) ... done
#   Created wheel for pyperclip: filename=pyperclip-1.9.0-py3-none-any.whl size=11003 sha256=0c454bc78fcdaf9d9551927bbe0037565412be0c21d8f7d6c099c3b413f797c7
#   Stored in directory: /Users/daniyar/Library/Caches/pip/wheels/e8/e7/56/591cb88ba1783b38c40d584026e766aac9c3a048e34128ce8b
# Successfully built ee pyperclip
# Installing collected packages: pyperclip, colour, webcolors, uritemplate, uri-template, traittypes, scooby, rsa, ratelim, python-box, pyshp, proto-plus, jupyter-leaflet, httplib2, googleapis-common-protos, google-crc32c, fqdn, blessings, google-resumable-media, google-auth, geocoder, ee, branca, isoduration, google-auth-httplib2, google-api-core, folium, google-cloud-core, google-api-python-client, google-cloud-storage, earthengine-api, eerepr, ipytree, ipyleaflet, ipyfilechooser, ipyevents, bqplot, geemap
# Successfully installed blessings-1.7 bqplot-0.12.43 branca-0.8.0 colour-0.1.5 earthengine-api-1.1.2 ee-0.2 eerepr-0.0.4 folium-0.17.0 fqdn-1.5.1 geemap-0.34.5 geocoder-1.38.1 google-api-core-2.20.0 google-api-python-client-2.147.0 google-auth-2.35.0 google-auth-httplib2-0.2.0 google-cloud-core-2.4.1 google-cloud-storage-2.18.2 google-crc32c-1.6.0 google-resumable-media-2.7.2 googleapis-common-protos-1.65.0 httplib2-0.22.0 ipyevents-2.0.2 ipyfilechooser-0.6.0 ipyleaflet-0.19.2 ipytree-0.2.2 isoduration-20.11.0 jupyter-leaflet-0.19.2 proto-plus-1.24.0 pyperclip-1.9.0 pyshp-2.3.1 python-box-7.2.0 ratelim-0.1.6 rsa-4.9 scooby-0.10.0 traittypes-0.2.1 uri-template-1.3.0 uritemplate-4.1.1 webcolors-24.8.0

# %%
import ee
import geemap.core as geemap

# %%
def mask_s2_clouds(image):
  """Masks clouds in a Sentinel-2 image using the QA band.

  Args:
      image (ee.Image): A Sentinel-2 image.

  Returns:
      ee.Image: A cloud-masked Sentinel-2 image.
  """
  qa = image.select('QA60')

  # Bits 10 and 11 are clouds and cirrus, respectively.
  cloud_bit_mask = 1 << 10
  cirrus_bit_mask = 1 << 11

  # Both flags should be set to zero, indicating clear conditions.
  mask = (
      qa.bitwiseAnd(cloud_bit_mask)
      .eq(0)
      .And(qa.bitwiseAnd(cirrus_bit_mask).eq(0))
  )

  return image.updateMask(mask).divide(10000)


dataset = (
    ee.ImageCollection('COPERNICUS/S2_SR_HARMONIZED')
    .filterDate('2020-01-01', '2020-01-30')
    # Pre-filter to get less cloudy granules.
    .filter(ee.Filter.lt('CLOUDY_PIXEL_PERCENTAGE', 20))
    .map(mask_s2_clouds)
)

visualization = {
    'min': 0.0,
    'max': 0.3,
    'bands': ['B4', 'B3', 'B2'],
}

m = geemap.Map()
m.set_center(83.277, 17.7009, 12)
m.add_layer(dataset.mean(), visualization, 'RGB')
m
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# ---------------------------------------------------------------------------
# EEException                               Traceback (most recent call last)
# Cell In[5], line 27
#      17   mask = (
#      18       qa.bitwiseAnd(cloud_bit_mask)
#      19       .eq(0)
#      20       .And(qa.bitwiseAnd(cirrus_bit_mask).eq(0))
#      21   )
#      23   return image.updateMask(mask).divide(10000)
#      26 dataset = (
# ---> 27     ee.ImageCollection('COPERNICUS/S2_SR_HARMONIZED')
#      28     .filterDate('2020-01-01', '2020-01-30')
#      29     # Pre-filter to get less cloudy granules.
#      30     .filter(ee.Filter.lt('CLOUDY_PIXEL_PERCENTAGE', 20))
#      31     .map(mask_s2_clouds)
#      32 )
#      34 visualization = {
#      35     'min': 0.0,
#      36     'max': 0.3,
#      37     'bands': ['B4', 'B3', 'B2'],
#      38 }
#      40 m = geemap.Map()
#
# File /opt/anaconda3/lib/python3.11/site-packages/ee/computedobject.py:28, in ComputedObjectMetaclass.__call__(cls, *args, **kwargs)
#      26   return args[0]
#      27 else:
# ---> 28   return type.__call__(cls, *args, **kwargs)
#
# File /opt/anaconda3/lib/python3.11/site-packages/ee/deprecation.py:124, in WarnForDeprecatedAsset.<locals>.Decorator.<locals>.Wrapper(*args, **kwargs)
#     122   if asset:
#     123     _IssueAssetDeprecationWarning(asset)
# --> 124 return func(*args, **kwargs)
#
# File /opt/anaconda3/lib/python3.11/site-packages/ee/imagecollection.py:44, in ImageCollection.__init__(self, args)
#      29 @deprecation.WarnForDeprecatedAsset('args')
#      30 def __init__(self, args: Any):
#      31   """ImageCollection constructor.
#      32
#      33   Args:
#    (...)
#      42     EEException: if passed something other than the above.
#      43   """
# ---> 44   self.initialize()
#      46   # Wrap single images in an array.
#      47   if isinstance(args, image.Image):
#
# File /opt/anaconda3/lib/python3.11/site-packages/ee/imagecollection.py:78, in ImageCollection.initialize(cls)
#      76 """Imports API functions to this class."""
#      77 if not cls._initialized:
# ---> 78   super().initialize()
#      79   apifunction.ApiFunction.importApi(cls, cls.name(), cls.name())
#      80   apifunction.ApiFunction.importApi(cls, 'reduce', cls.name())
#
# File /opt/anaconda3/lib/python3.11/site-packages/ee/collection.py:50, in Collection.initialize(cls)
#      48 """Imports API functions to this class."""
#      49 if not cls._initialized:
# ---> 50   apifunction.ApiFunction.importApi(cls, cls.name(), cls.name())
#      51   apifunction.ApiFunction.importApi(
#      52       cls, 'AggregateFeatureCollection', cls.name(), 'aggregate_')
#      53   cls._initialized = True
#
# File /opt/anaconda3/lib/python3.11/site-packages/ee/_utils.py:38, in accept_opt_prefix.<locals>.opt_fixed.<locals>.wrapper(*args, **kwargs)
#      36     if new_key not in kwargs:
#      37       kwargs[new_key] = old_key_val
# ---> 38 return func(*args, **kwargs)
#
# File /opt/anaconda3/lib/python3.11/site-packages/ee/apifunction.py:197, in ApiFunction.importApi(cls, target, prefix, type_name, prepend)
#     177 @classmethod
#     178 @_utils.accept_opt_prefix('opt_prepend')
#     179 def importApi(
#    (...)
#     184     prepend: Optional[str] = None,
#     185 ) -> None:
#     186   """Adds all API functions that begin with a given prefix to a target class.
#     187
#     188   Args:
#    (...)
#     195       functions.
#     196   """
# --> 197   cls.initialize()
#     198   prepend = prepend or ''
#     199   for name, api_func in cls._api.items():
#
# File /opt/anaconda3/lib/python3.11/site-packages/ee/apifunction.py:161, in ApiFunction.initialize(cls)
#     159 """Initializes the list of signatures from the Earth Engine front-end."""
#     160 if not cls._api:
# --> 161   signatures = data.getAlgorithms()
#     162   api = {}
#     163   for name, sig in signatures.items():
#     164     # Strip type parameters.
#
# File /opt/anaconda3/lib/python3.11/site-packages/ee/data.py:1479, in getAlgorithms()
#    1462 """Get the list of algorithms.
#    1463
#    1464 Returns:
#    (...)
#    1475               is not specified.
#    1476 """
#    1477 try:
#    1478   call = (
# -> 1479       _get_cloud_projects()
#    1480       .algorithms()
#    1481       .list(parent=_get_projects_path(), prettyPrint=False)
#    1482   )
#    1483 except TypeError:
#    1484   call = (
#    1485       _get_cloud_projects()
#    1486       .algorithms()
#    1487       .list(project=_get_projects_path(), prettyPrint=False)
#    1488   )
#
# File /opt/anaconda3/lib/python3.11/site-packages/ee/data.py:350, in _get_cloud_projects()
#     348 def _get_cloud_projects() -> Any:
#     349   if _cloud_api_resource is None:
# --> 350     raise ee_exception.EEException(_NOT_INITIALIZED_MESSAGE)
#     351   return _cloud_api_resource.projects()
#
# EEException: Earth Engine client library not initialized. See http://goo.gle/ee-auth.
